# %% [markdown]
# <span style="font-size:24px;">Introduction to Apache Spark and Lab Overview<span>
#
# <span style="font-size:16px;">
# Apache Spark is an open-source, distributed computing system designed for processing large-scale data quickly and efficiently. It provides an intuitive programming model for working with structured and unstructured data, enabling users to perform transformations and actions on datasets using high-level APIs. Spark's key features include:
# <span>
#
# #
# - <span style="font-size:16px;">Speed: Spark processes data in memory, making it significantly faster than traditional disk-based frameworks like Hadoop MapReduce.<span>
# - <span style="font-size:16px;">Scalability: It can scale seamlessly from a single machine to thousands of nodes in a cluster.<span>
# - <span style="font-size:16px;">Versatility: Spark supports multiple workloads, including batch processing, interactive querying, streaming, machine learning, and graph processing.<span>
#
# <span style="font-size:16px;">
# At the core of Spark lies the Resilient Distributed Dataset (RDD), a fault-tolerant and immutable data abstraction that enables distributed data processing. Transformations on RDDs are executed lazily, building a lineage graph that allows efficient fault recovery.
# <span>

# %% [markdown]
# <span style="font-size:24px;">About the Lab<span>
#
# <span style="font-size:16px;">
# This lab introduces key concepts and applications of Apache Spark using PySpark, Spark's Python API.<span>
#
# #
# 1. <span style="font-size:16px;">Basic Operations: <span>
#     - <span style="font-size:16px;">Working with RDDs: Creation, transformations, and actions.<span>
#     - <span style="font-size:16px;">Common transformations like map, flatMap, and groupByKey.<span>
#     - <span style="font-size:16px;">Joining and aggregating datasets.<span>
# 2. <span style="font-size:16px;">Spark optimisations:<span>
#     - <span style="font-size:16px;">Lineage tracking<span>
#     - <span style="font-size:16px;">Lazy evaluation.<span>
#     - <span style="font-size:16px;">Caching<span>
#     - <span style="font-size:16px;">Checkpointing<span>
# 3. <span style="font-size:16px;">Spark UI<span>
# 4. <span style="font-size:16px;">Data Analytics with spark<span>
# <span>

# %% [markdown]
# <span style="font-size:24px;">Installing pyspark<span>
#
# <span style="font-size:16px;"> Ensure that you have python>=3.8 and JDK>=8.<span>
#
# <span style="font-size:16px;">We can start by first installing executing the following command in your terminal/command prompt:<span>
#
# <span style="font-size:20px;">pip install pyspark<span>
#
# <span style="font-size:16px;">The same can be achieved by executing the following codeblock:<span>

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /opt/anaconda3/lib/python3.11/site-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /opt/anaconda3/lib/python3.11/site-packages (from pyspark) (0.10.9.7)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <span style="font-size:16px;">We can verify that the installation by running the given codeblock.<span>

# %%
import pyspark
print(pyspark.__version__)
# Out:
# 3.5.1

# %% [markdown]
# <span style="font-size:16px;">It is also recommended to install "findspark" since we are using a Jupyter Notebook.
# This can be done by running the following command in the terminal.<span>
#
# <span style="font-size:20px;">pip install findspark<span>
#
# <span style="font-size:16px;">This can also be done by executing the given codeblock.<span>

# %%
# %pip install findspark
# Out:
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl.metadata (352 bytes)
# Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <span style="font-size:16px;">The next step is to import and initialize findspark.<span>

# %%
import findspark
findspark.init()

# %% [markdown]
# <span style="font-size:16px;"> Now that the setup is complete, we can proceed to initialize a Spark context. The Spark context serves as the entry point to interact with Spark’s core functionalities, allowing us to create and manipulate RDDs, perform transformations, and execute actions across a cluster. </span>

# %%
from pyspark import SparkContext

# Initialize Spark
sc = SparkContext("local","SparkLab")
sc.setCheckpointDir('checkpoint')
# Out:
# 24/12/03 13:38:03 WARN Utils: Your hostname, Samyaks-MacBook-Air.local resolves to a loopback address: 127.0.0.1; using 10.194.219.93 instead (on interface en0)
# 24/12/03 13:38:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/03 13:38:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# <span style="font-size:16px;"> When initializing the Spark context for the first time, you may encounter some warnings displaying the address and port number. Make sure to note these details, as they will be useful later for accessing SparkUI. By default, the address is set to 'localhost' and port to 4000.
# Since pyspark only allows to run one context at a time, you need to stop an older context before creating a new one. This can be done by the stop() function. </span>

# %%
# Dont run this cell now
sc.stop()

# %% [markdown]
# <span style="font-size:16px;">Once your Spark context is set up, you can begin creating Resilient Distributed Datasets (RDDs). Pyspark has multiple methods to convert different datatypes into rdd.<span>

# %%
# Create an RDD from a Python list
data = [1, 2, 3, 4, 5]
rdd_list = sc.parallelize(data)

# Verify RDD content
print(rdd_list.collect())  # Output: [1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# Path to the file
file_path = "sample.txt"

# Create a sample file
with open(file_path, "w") as file:
    file.write("Hello, World!\n")
    file.write("This is a sample file")

# Load the file into an RDD
rdd_file = sc.textFile(file_path)

# Verify RDD content
print(rdd_file.collect())  # Output: ['Hello, World!', 'This is a sample file']
# Out:
# ['Hello, World!', 'This is a sample file']

# %% [markdown]
# <span style="font-size:16px;"> The collect() action retrieves the entire RDD as a list to the driver. This is useful for small datasets or debugging.<span>
#
# <span style="font-size:16px;"> We can apply various map and reduce type transformations to these rdd. Examples of some have been given below.<span>

# %%
# Apply map transformation to square each element
squared_rdd = rdd_list.map(lambda x: x ** 2)

# Collect and print the result
print(squared_rdd.collect())  # Output: [1, 4, 9, 16, 25]

#------------------------------------------------------------------------------------------------------------

# Apply filter transformation to select even numbers
even_rdd = rdd_list.filter(lambda x: x % 2 == 0)

# Collect and print the result
print(even_rdd.collect())  # Output: [2, 4]

#------------------------------------------------------------------------------------------------------------

# Apply flatMap transformation to split words in a sentence
sentences = ["Spark is great", "RDDs are powerful"]
sentences_rdd = sc.parallelize(sentences)

# FlatMap to split sentences into words
words_rdd = sentences_rdd.flatMap(lambda sentence: sentence.split(" "))

# Collect and print the result
print(words_rdd.collect())  # Output: ['Spark', 'is', 'great', 'RDDs', 'are', 'powerful']

#------------------------------------------------------------------------------------------------------------

# Apply reduce to calculate the sum of the elements
sum_result = rdd_list.reduce(lambda x, y: x + y)

# Print the result
print(sum_result)  # Output: 15

#------------------------------------------------------------------------------------------------------------

# Count the number of elements
print(rdd_list.count())  # Output: 5

#------------------------------------------------------------------------------------------------------------

# Take the first 3 elements
print(rdd_list.take(3))  # Output: [1, 2, 3]

#------------------------------------------------------------------------------------------------------------

# Group elements by their parity (even or odd)
grouped_rdd = rdd_list.groupBy(lambda x: 'even' if x % 2 == 0 else 'odd')

# Collect and print the result
print(grouped_rdd.collect())
# Output: [('odd', [1, 3, 5]), ('even', [2, 4])] or [('even', iter([2, 4])), ('odd', iter([1, 3, 5]))]

#------------------------------------------------------------------------------------------------------------

# Create two RDDs
rdd1 = sc.parallelize([1, 2, 3])
rdd2 = sc.parallelize([4, 5, 6])

# Perform union
union_rdd = rdd1.union(rdd2)

# Collect and print the result
print(union_rdd.collect())  # Output: [1, 2, 3, 4, 5, 6]

#------------------------------------------------------------------------------------------------------------

# Create an RDD with duplicates
rdd_with_duplicates = sc.parallelize([1, 2, 2, 3, 3, 4])

# Apply distinct transformation
distinct_rdd = rdd_with_duplicates.distinct()

# Collect and print the result
print(distinct_rdd.collect())  # Output: [1, 2, 3, 4]

#------------------------------------------------------------------------------------------------------------

# Create an RDD of key-value pairs
pair_rdd = sc.parallelize([('a', 1), ('b', 2), ('a', 3), ('b', 4)])

# Apply reduceByKey to sum the values with the same key
reduced_rdd = pair_rdd.reduceByKey(lambda x, y: x + y)

# Collect and print the result
print(reduced_rdd.collect())  # Output: [('a', 4), ('b', 6)]

#------------------------------------------------------------------------------------------------------------

# Create an RDD of key-value pairs
pair_rdd = sc.parallelize([('a', 1), ('b', 2), ('c', 3)])

# Apply mapValues to increment each value by 1
mapped_values_rdd = pair_rdd.mapValues(lambda x: x + 1)

# Collect and print the result
print(mapped_values_rdd.collect())  # Output: [('a', 2), ('b', 3), ('c', 4)]

#------------------------------------------------------------------------------------------------------------

# Sample 50% of the RDD elements
sampled_rdd = rdd_list.sample(withReplacement=False, fraction=0.5)

# Collect and print the result
print(sampled_rdd.collect())

#------------------------------------------------------------------------------------------------------------

key_value_rdd = sc.parallelize([('a', 1), ('b', 2), ('c', 3), ('a', 4)])

# Apply mapValues to increment each value by 1
mapped_values_rdd = key_value_rdd.mapValues(lambda x: x + 1)

# Collect and print the result
print(mapped_values_rdd.collect())  # Output: [('a', 2), ('b', 3), ('c', 4), ('a', 5)]
# Out:
# [1, 4, 9, 16, 25]
# [2, 4]
# ['Spark', 'is', 'great', 'RDDs', 'are', 'powerful']
# 15
# 5
# [1, 2, 3]
# [('odd', <pyspark.resultiterable.ResultIterable object at 0x100b82e90>), ('even', <pyspark.resultiterable.ResultIterable object at 0x127e4b110>)]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4]
# [('a', 4), ('b', 6)]
# [('a', 2), ('b', 3), ('c', 4)]
# [1, 3, 5]
# [('a', 2), ('b', 3), ('c', 4), ('a', 5)]

# %% [markdown]
# <span style="font-size:16px;"> One of the flagship features of RDD is lineage tracking. We can see the lineage of a RDD by using the toDebugString() function. We can also observe the break in the lineage by creating a checkpoint using the checkpoint() function.<span>

# %%
rdd_first = sc.parallelize([1, 2, 3])
rdd_second = rdd_first.map(lambda x: x * 2)

print("RDD Lineage:", rdd_second.toDebugString())

rdd_first.checkpoint()
print(rdd_first.collect())

print(rdd_first.isCheckpointed())

print("RDD Lineage after checkpoint:", rdd_second.toDebugString())
# Out:
# RDD Lineage: b'(1) PythonRDD[36] at RDD at PythonRDD.scala:53 []\n |  ParallelCollectionRDD[35] at readRDDFromFile at PythonRDD.scala:289 []'
# [1, 2, 3]
# True
# RDD Lineage after checkpoint: b'(1) PythonRDD[36] at RDD at PythonRDD.scala:53 []\n |  ParallelCollectionRDD[35] at readRDDFromFile at PythonRDD.scala:289 []\n |  ReliableCheckpointRDD[37] at collect at /var/folders/7w/tfyt6rt124n73xvzq62ryd7m0000gn/T/ipykernel_76547/2310518397.py:7 []'

# %% [markdown]
# <span style="font-size:16px;"> To improve performance, spark adopts a lazy execution policy. We can observe this in the following code.<span>

# %%
import time

def square(x):
    call_time = time.time()
    print(f"Called with {x} at {call_time}")
    return x ** 2

squared_rdd = rdd_list.map(square)
exec_time = time.time()
print("Execution time:", exec_time)

print(squared_rdd.collect())
# Out:
# Execution time: 1733213661.7255712
# [1, 4, 9, 16, 25]
# Called with 1 at 1733213661.815682
# Called with 2 at 1733213661.8157718
# Called with 3 at 1733213661.815775
# Called with 4 at 1733213661.815781
# Called with 5 at 1733213661.815783

# %% [markdown]
# <span style="font-size:16px;"> Another optimization you can use is caching the RDD. A stronger version of this is persist() which can be used to save the Rdd to the disk.<span>

# %%
# Without cache
start = time.time()
print("Sum Without Cache:", rdd_list.reduce(lambda x, y: x + y))
print("Time Without Cache:", time.time() - start)

# With cache
rdd_list.cache()
start = time.time()
print("Sum With Cache:", rdd_list.reduce(lambda x, y: x + y))
print("Time With Cache:", time.time() - start)
# Out:
# Sum Without Cache: 15
# Time Without Cache: 0.0972452163696289
# Sum With Cache: 15
# Time With Cache: 0.07113099098205566

# %% [markdown]
# <span style="font-size:24px;">Spark UI Overview<span>
#
# <span style="font-size:16px;">
# By default, Spark UI is accessible at http://<driver-host>:4040 while the application is running. If a different address or port is used, pyspark notifies the user during context creation.
#
# Key Features:<span>
#
# #
# - <span style="font-size:16px;">Job Tab<span>
#     - <span style="font-size:16px;">Lists all the jobs in the application with details such as:<span>
#         - <span style="font-size:16px;">Job ID: A unique identifier for each job.<span>
#         - <span style="font-size:16px;">Status: Indicates whether a job is completed, running, or failed.<span>
#         - <span style="font-size:16px;">Duration: The time taken for the job to execute.<span>
#         - <span style="font-size:16px;">Stages: Shows the stages involved in the job.<span>
#     - <span style="font-size:16px;">Provides a visualization of the DAG (Directed Acyclic Graph) of stages and their dependencies.<span>
#
# - <span style="font-size:16px;">Stages Tab<span>
#     - <span style="font-size:16px;">Displays detailed information about each stage of the application:<span>
#         - <span style="font-size:16px;">Stage ID: Unique identifier for each stage.<span>
#         - <span style="font-size:16px;">Task Summary: Number of tasks, their status (e.g., succeeded, failed, or pending).<span>
#         - <span style="font-size:16px;">Input/Output Data: Data read/written during the stage.<span>
#         - <span style="font-size:16px;">Shuffle Read/Write: Details about shuffle operations.<span>
#     - <span style="font-size:16px;">Aggregated Metrics: Task execution times, shuffle data, and resource usage.<span>
#
# - <span style="font-size:16px;">Storage Tab<span>
#     - <span style="font-size:16px;">Lists all the RDDs or datasets currently cached or persisted.<span>
#     - <span style="font-size:16px;">Provides details such as:<span>
#         - <span style="font-size:16px;">RDD ID: Unique identifier for each RDD.<span>
#         - <span style="font-size:16px;">Storage Level: Type of storage used (e.g., MEMORY_ONLY, DISK_ONLY).<span>
#         - <span style="font-size:16px;">Partitions: Number of partitions and their sizes.<span>
#         - <span style="font-size:16px;">Memory/Disk Usage: Amount of data stored in memory or on disk.<span>
# <span>

# %% [markdown]
# <span style="font-size:24px;">Analytics using Spark<span>
#
# <span style="font-size:16px;">
# You are given csv file containing the website logs for the quiz you took. Using these, you have to identify all the cheaters.
#
# The csv file has the following columns:
# 1. 'Time': The timestamp in the format "%d/%m/%y; %H:%M:%S".
# 2. 'UserId': The unique Id of the user.
# 3. 'Event context': The current screen/webpage visible to the user.
# 4. 'Component': Type of interface visible to the user.
# 5. 'Event name': The action performed by the user.
# 6. 'Description': A detailed description of the action.
#
# ('Event context' column is a refinement of the 'Component' column.)
#
# You can conclude someone is a cheater if they answer a question significantly quicker than the average time for that problem. For generalization, Someone is a cheater if first response time is less than 1/5 times the average for that problem.
#
# A suggested roadmap for the problem is:
# - Load the file into a Rdd.
# - Convert this Rdd to a Rdd with suitable format like lists or dictionaries.
# - Remove all logs not related to the quiz.(Hint: Apply a filter on the 'Component' column.)
# - Group the logs for each user.
# - For each user, group the logs by the problem type.
# - For each problem, find when it was first viewed and submitted.
# - Calculate the time taken for each problem by each user.
# - Calculate the average time taken for each problem.
# - Compare these to every user and identify the cheaters.
#
# You can also try computing the following:
# - Which users did not attempt the quiz.
# - Who was the Early Bird.( Which user was the first to attempt the quiz.)
# - Who completed all the questions the fastest.
# - What was the maximum and minimum time taken for each problem.
# - For each problem, who solved it the quickest.
# <span>

# %%
# %%bash
# tree
# Out:
# .
# ├── checkpoint
# │   └── e2d5d2f7-a10c-4f2b-bc29-f1da8be9fac8
# │       └── rdd-35
# │           └── part-00000
# ├── lab2.ipynb
# ├── sample.txt
# └── ws-logs_filtered.csv
#
# 4 directories, 4 files

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from datetime import datetime

spark = SparkSession.builder.appName("CheaterDetection").getOrCreate()

# %%
csv_file_path = "ws-logs_filtered.csv" 
data_rdd = spark.read.csv(csv_file_path, header=True).rdd

# %%
# Parse timestamps and clean data
def parse_row(row):
    try:
        row["Time"] = datetime.strptime(row["Time"], "%d/%m/%y; %H:%M:%S")
    except ValueError:
        row["Time"] = None
    return row

data_rdd = data_rdd.map(lambda row: row.asDict()).map(parse_row).filter(lambda row: row["Time"] is not None)

# %%
# Filter quiz-related logs
quiz_rdd = data_rdd.filter(lambda row: "quiz" in row["Component"].lower() or "quiz" in row["Event context"].lower())

# %%
grouped_by_user_rdd = quiz_rdd.groupBy(lambda row: row["UserId"])

# %%
def process_user_logs(user_logs):
    user_id, logs = user_logs
    logs = list(logs)
    problems = {}

    for log in logs:
        problem = log["Event context"]
        if problem not in problems:
            problems[problem] = {"first_viewed": None, "submitted": None}

        if "viewed" in log["Event name"].lower():
            if not problems[problem]["first_viewed"]:
                problems[problem]["first_viewed"] = log["Time"]
        elif "submit" in log["Event name"].lower():
            problems[problem]["submitted"] = log["Time"]

    cheater_problems = []
    time_taken = {}

    for problem, times in problems.items():
        if times["first_viewed"] and times["submitted"]:
            duration = (times["submitted"] - times["first_viewed"]).total_seconds()
            time_taken[problem] = duration

    return {
        "UserId": user_id,
        "TimeTaken": time_taken,
    }

user_analysis_rdd = grouped_by_user_rdd.map(process_user_logs)

# Collect results and identify cheaters
results = user_analysis_rdd.collect()

# Display user analysis
for user in results:
    print(f"User ID: {user['UserId']}")
    print(f"Time Taken: {user['TimeTaken']}")
    print("-" * 50)
# Out:
# User ID: user104
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 37982.0}
# --------------------------------------------------
# User ID: user161
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 36694.0}
# --------------------------------------------------
# User ID: user057
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 35171.0}
# --------------------------------------------------
# User ID: user108
# Time Taken: {}
# --------------------------------------------------
# User ID: user025
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 37807.0}
# --------------------------------------------------
# User ID: user079
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 36097.0}
# --------------------------------------------------
# User ID: user151
# Time Taken: {}
# --------------------------------------------------
# User ID: user096
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 34879.0}
# --------------------------------------------------
# User ID: user066
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 34800.0}
# --------------------------------------------------
# User ID: user142
# Time Taken: {}
# --------------------------------------------------
# User ID: user173
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 30800.0}
# --------------------------------------------------
# User ID: user139
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 32238.0}
# --------------------------------------------------
# User ID: user126
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 32379.0}
# --------------------------------------------------
# User ID: user153
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 27762.0}
# --------------------------------------------------
# User ID: user068
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 17762.0}
# --------------------------------------------------
# User ID: user089
# Time Taken: {}
# --------------------------------------------------
# User ID: user008
# Time Taken: {}
# --------------------------------------------------
# User ID: user072
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 9610.0}
# --------------------------------------------------
# User ID: user040
# Time Taken: {}
# --------------------------------------------------
# User ID: user011
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 8468.0}
# --------------------------------------------------
# User ID: user067
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 8128.0}
# --------------------------------------------------
# User ID: user152
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 8962.0}
# --------------------------------------------------
# User ID: user171
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 6880.0}
# --------------------------------------------------
# User ID: user141
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4837.0}
# --------------------------------------------------
# User ID: user125
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 7007.0}
# --------------------------------------------------
# User ID: user164
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 6284.0}
# --------------------------------------------------
# User ID: user123
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 6628.0}
# --------------------------------------------------
# User ID: user009
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 5941.0}
# --------------------------------------------------
# User ID: user080
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 6692.0}
# --------------------------------------------------
# User ID: user065
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 6245.0}
# --------------------------------------------------
# User ID: user071
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 6311.0}
# --------------------------------------------------
# User ID: user156
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 5202.0}
# --------------------------------------------------
# User ID: user047
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 5742.0}
# --------------------------------------------------
# User ID: user124
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 5795.0}
# --------------------------------------------------
# User ID: user010
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4746.0}
# --------------------------------------------------
# User ID: user005
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2941.0}
# --------------------------------------------------
# User ID: user100
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 5169.0}
# --------------------------------------------------
# User ID: user022
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 5110.0}
# --------------------------------------------------
# User ID: user120
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2550.0}
# --------------------------------------------------
# User ID: user085
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4844.0}
# --------------------------------------------------
# User ID: user032
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2561.0}
# --------------------------------------------------
# User ID: user088
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4861.0}
# --------------------------------------------------
# User ID: user034
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4715.0}
# --------------------------------------------------
# User ID: user045
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1974.0}
# --------------------------------------------------
# User ID: user101
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4604.0}
# --------------------------------------------------
# User ID: user140
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4026.0}
# --------------------------------------------------
# User ID: user021
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4508.0}
# --------------------------------------------------
# User ID: user003
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2024.0}
# --------------------------------------------------
# User ID: user052
# Time Taken: {}
# --------------------------------------------------
# User ID: user031
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4488.0}
# --------------------------------------------------
# User ID: user130
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2163.0}
# --------------------------------------------------
# User ID: user004
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4104.0}
# --------------------------------------------------
# User ID: user027
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1157.0}
# --------------------------------------------------
# User ID: user091
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4123.0}
# --------------------------------------------------
# User ID: user043
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2127.0}
# --------------------------------------------------
# User ID: user135
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3986.0}
# --------------------------------------------------
# User ID: user129
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4232.0}
# --------------------------------------------------
# User ID: user051
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4261.0}
# --------------------------------------------------
# User ID: user103
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3473.0}
# --------------------------------------------------
# User ID: user026
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4162.0}
# --------------------------------------------------
# User ID: user013
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4068.0}
# --------------------------------------------------
# User ID: user074
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4222.0}
# --------------------------------------------------
# User ID: user016
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1886.0}
# --------------------------------------------------
# User ID: user157
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2523.0}
# --------------------------------------------------
# User ID: user082
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1759.0}
# --------------------------------------------------
# User ID: user150
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3734.0}
# --------------------------------------------------
# User ID: user049
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1565.0}
# --------------------------------------------------
# User ID: user098
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3847.0}
# --------------------------------------------------
# User ID: user035
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 4023.0}
# --------------------------------------------------
# User ID: user166
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3665.0}
# --------------------------------------------------
# User ID: user169
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1653.0}
# --------------------------------------------------
# User ID: user041
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3947.0}
# --------------------------------------------------
# User ID: user109
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3664.0}
# --------------------------------------------------
# User ID: user121
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3431.0}
# --------------------------------------------------
# User ID: user113
# Time Taken: {}
# --------------------------------------------------
# User ID: user086
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3269.0}
# --------------------------------------------------
# User ID: user144
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1526.0}
# --------------------------------------------------
# User ID: user020
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3888.0}
# --------------------------------------------------
# User ID: user038
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3756.0}
# --------------------------------------------------
# User ID: user064
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3470.0}
# --------------------------------------------------
# User ID: user147
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3825.0}
# --------------------------------------------------
# User ID: user039
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1687.0}
# --------------------------------------------------
# User ID: user148
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3670.0}
# --------------------------------------------------
# User ID: user146
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1482.0}
# --------------------------------------------------
# User ID: user154
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 919.0}
# --------------------------------------------------
# User ID: user168
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1573.0}
# --------------------------------------------------
# User ID: user028
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1953.0}
# --------------------------------------------------
# User ID: user015
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1215.0}
# --------------------------------------------------
# User ID: user158
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2269.0}
# --------------------------------------------------
# User ID: user163
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3426.0}
# --------------------------------------------------
# User ID: user001
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3356.0}
# --------------------------------------------------
# User ID: user058
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3075.0}
# --------------------------------------------------
# User ID: user042
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3322.0}
# --------------------------------------------------
# User ID: user118
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 821.0}
# --------------------------------------------------
# User ID: user162
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1671.0}
# --------------------------------------------------
# User ID: user119
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3436.0}
# --------------------------------------------------
# User ID: user084
# Time Taken: {}
# --------------------------------------------------
# User ID: user159
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3165.0}
# --------------------------------------------------
# User ID: user127
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 985.0}
# --------------------------------------------------
# User ID: user056
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3588.0}
# --------------------------------------------------
# User ID: user106
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3537.0}
# --------------------------------------------------
# User ID: user069
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3375.0}
# --------------------------------------------------
# User ID: user170
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2787.0}
# --------------------------------------------------
# User ID: user155
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2205.0}
# --------------------------------------------------
# User ID: user060
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3418.0}
# --------------------------------------------------
# User ID: user134
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 970.0}
# --------------------------------------------------
# User ID: user077
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2185.0}
# --------------------------------------------------
# User ID: user075
# Time Taken: {}
# --------------------------------------------------
# User ID: user165
# Time Taken: {}
# --------------------------------------------------
# User ID: user136
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3537.0}
# --------------------------------------------------
# User ID: user076
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2200.0}
# --------------------------------------------------
# User ID: user017
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2377.0}
# --------------------------------------------------
# User ID: user132
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1717.0}
# --------------------------------------------------
# User ID: user128
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2554.0}
# --------------------------------------------------
# User ID: user055
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1733.0}
# --------------------------------------------------
# User ID: user145
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2447.0}
# --------------------------------------------------
# User ID: user167
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2999.0}
# --------------------------------------------------
# User ID: user070
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 747.0}
# --------------------------------------------------
# User ID: user029
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2165.0}
# --------------------------------------------------
# User ID: user093
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2013.0}
# --------------------------------------------------
# User ID: user023
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 949.0}
# --------------------------------------------------
# User ID: user133
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 662.0}
# --------------------------------------------------
# User ID: user061
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1762.0}
# --------------------------------------------------
# User ID: user006
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1718.0}
# --------------------------------------------------
# User ID: user090
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 634.0}
# --------------------------------------------------
# User ID: user138
# Time Taken: {}
# --------------------------------------------------
# User ID: user110
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2403.0}
# --------------------------------------------------
# User ID: user063
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1200.0}
# --------------------------------------------------
# User ID: user097
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 990.0}
# --------------------------------------------------
# User ID: user143
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2571.0}
# --------------------------------------------------
# User ID: user111
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2247.0}
# --------------------------------------------------
# User ID: user112
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 2109.0}
# --------------------------------------------------
# User ID: user059
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1334.0}
# --------------------------------------------------
# User ID: user107
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 444.0}
# --------------------------------------------------
# User ID: user046
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 525.0}
# --------------------------------------------------
# User ID: user149
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 460.0}
# --------------------------------------------------
# User ID: user137
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1348.0}
# --------------------------------------------------
# User ID: user105
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 843.0}
# --------------------------------------------------
# User ID: user050
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1332.0}
# --------------------------------------------------
# User ID: user014
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1270.0}
# --------------------------------------------------
# User ID: user117
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1076.0}
# --------------------------------------------------
# User ID: user048
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 788.0}
# --------------------------------------------------
# User ID: user099
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 716.0}
# --------------------------------------------------
# User ID: user081
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 598.0}
# --------------------------------------------------
# User ID: user083
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 487.0}
# --------------------------------------------------
# User ID: user053
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 487.0}
# --------------------------------------------------
# User ID: user044
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 177.0}
# --------------------------------------------------
# User ID: user174
# Time Taken: {}
# --------------------------------------------------
# User ID: user087
# Time Taken: {}
# --------------------------------------------------
# User ID: user019
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 986.0}
# --------------------------------------------------
# User ID: user033
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 1307.0}
# --------------------------------------------------
# User ID: user102
# Time Taken: {}
# --------------------------------------------------
# User ID: user114
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 3523.0}
# --------------------------------------------------
# User ID: user062
# Time Taken: {'Quiz: Multiple Choice Questions (14 marks)': 481.0}
# --------------------------------------------------

# %%
# Finding the Early Bird
first_attempt = quiz_logs_rdd.map(lambda row: (row["UserId"], row["Time"])).reduce(lambda a, b: a if a[1] < b[1] else b)
print(f"Early Bird: User {first_attempt[0]}")
# Out:
# Early Bird: User user104

# %%
# Finding who completed all questions the fastest
fastest_completion = sorted(results, key=lambda user: sum(user["TimeTaken"].values()))[0]

print(f"Fastest Completer: User {fastest_completion['UserId']}")
# Out:
# Fastest Completer: User user108

# %%
# Maximum and minimum times for each problem
all_problems_times = quiz_logs_rdd.map(lambda row: (row["Event context"], row["Time"])).groupByKey().mapValues(list)
max_min_times = all_problems_times.mapValues(lambda times: (max(times), min(times))).collect()

for problem, (max_time, min_time) in max_min_times:
    print(f"Problem: {problem}, Max Time: {max_time}, Min Time: {min_time}")
# Out:
# Problem: Quiz: Multiple Choice Questions (14 marks), Max Time: 2024-11-18 17:06:45, Min Time: 2024-11-17 00:03:22

# %%
import pandas as pd

# %%
df = pd.read_csv("ws-logs_filtered.csv")

# %%
df.head(20)
# Out:
#                   Time   UserId                               Event context  \
# 0   17/11/24; 00:00:55  user152  Course: Winter School 2024 on Data Systems
# 1   17/11/24; 00:01:07  user152                       User: Christopher Lee
# 2   17/11/24; 00:01:10  user083                                      System
# 3   17/11/24; 00:01:12  user083  Course: Winter School 2024 on Data Systems
# 4   17/11/24; 00:01:12  user083                                      System
# 5   17/11/24; 00:01:15  user083  Course: Winter School 2024 on Data Systems
# 6   17/11/24; 00:01:18  user152                                      System
# 7   17/11/24; 00:01:23  user083  Course: Winter School 2024 on Data Systems
# 8   17/11/24; 00:01:24  user152                       User: Christopher Lee
# 9   17/11/24; 00:01:29  user083                                      System
# 10  17/11/24; 00:01:47  user083  Course: Winter School 2024 on Data Systems
# 11  17/11/24; 00:01:51  user083        Virtual programming lab: Sample Code
# 12  17/11/24; 00:01:53  user083        Virtual programming lab: Sample Code
# 13  17/11/24; 00:01:53  user152                                   Site home
# 14  17/11/24; 00:01:58  user083        Virtual programming lab: Sample Code
# 15  17/11/24; 00:01:58  user083        Virtual programming lab: Sample Code
# 16  17/11/24; 00:01:59  user152                                   Site home
# 17  17/11/24; 00:02:03  user083        Virtual programming lab: Sample Code
# 18  17/11/24; 00:02:03  user083        Virtual programming lab: Sample Code
# 19  17/11/24; 00:02:07  user083        Virtual programming lab: Sample Code
#
#                   Component                       Event name  \
# 0                    System              User profile viewed
# 1                    System              User profile viewed
# 2                    System                User login failed
# 3                    System                    Course viewed
# 4                    System               User has logged in
# 5                    System                 User list viewed
# 6                    System              Blog entries viewed
# 7                    System              User profile viewed
# 8                     Forum               User report viewed
# 9                    System             Email failed to send
# 10              User report         Grade user report viewed
# 11  Virtual programming lab  mod_vpl: vpl description viewed
# 12  Virtual programming lab       mod_vpl: submission viewed
# 13          Overview report     Grade overview report viewed
# 14  Virtual programming lab       mod_vpl: submission edited
# 15  Virtual programming lab  mod_vpl: vpl description viewed
# 16          Overview report     Grade overview report viewed
# 17  Virtual programming lab    mod_vpl: submission evaluated
# 18  Virtual programming lab     mod_vpl: submission uploaded
# 19  Virtual programming lab       mod_vpl: submission viewed
#
#                                           Description
# 0   The user with id '2141' viewed the profile for...
# 1   The user with id '2141' viewed the profile for...
# 2   Login failed for user 'imejia@example.net'. Mo...
# 3   The user with id '2439' viewed the course with...
# 4              The user with id '2439' has logged in.
# 5   The user with id '2439' viewed the list of use...
# 6        The user with id '2141' viewed blog entries.
# 7   The user with id '2439' viewed the profile for...
# 8   The user with id '2141' has viewed the user re...
# 9   Failed to send an email from the user with id ...
# 10  The user with id '2439' viewed the user report...
# 11  The user with id 2439 viewed description of VP...
# 12  The user with id 2439 viewed  VPL submission w...
# 13  The user with id '2141' viewed the overview re...
# 14  The user with id 2439 edited  VPL submission w...
# 15  The user with id 2439 viewed description of VP...
# 16  The user with id '2141' viewed the overview re...
# 17  The user with id 2439 evaluated  VPL submissio...
# 18  The user with id 2439 uploaded  VPL submission...
# 19  The user with id 2439 viewed  VPL submission w...

# %%
# %%bash
# echo "# winter-school-iitd-lab2" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/jainsamyak15/winter-school-iitd-lab2.git
# git push -u origin main
# Out:
# Initialized empty Git repository in /Users/samyakjain/Downloads/lab2/.git/
# [main (root-commit) 1b0375d] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
# To https://github.com/jainsamyak15/winter-school-iitd-lab2.git
#  * [new branch]      main -> main
# branch 'main' set up to track 'origin/main'.

# %%
# %%bash
# git add .
# git commit -m "initial commit"
# git push origin main
# Out:
# UsageError: %%bash is a cell magic, but the cell body is empty.
